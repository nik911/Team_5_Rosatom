# %%
import numpy as np
import pygad

# Определение целевой функции
def fitness_function(solution, solution_idx):
    # Вычисление значения целевой функции для данного расписания
    # ...

    # Возвращение значения целевой функции
    return fitness_value

# Создание экземпляра генетического алгоритма
ga_instance = pygad.GA(num_generations=100,
                       num_parents_mating=10,
                       fitness_func=fitness_function)

# Запуск генетического алгоритма
ga_instance.run()

# Получение лучшего решения
best_solution = ga_instance.best_solution()
best_fitness = ga_instance.best_solution_fitness()

# Вывод результата
print("Лучшее решение:", best_solution)
print("Значение целевой функции:", best_fitness)
# Out:
# Error creating the initial population:
#
# When the parameter 'initial_population' is None, then the 2 parameters 'sol_per_pop' and 'num_genes' cannot be None too.
# There are 2 options to prepare the initial population:
# 1) Assinging the initial population to the 'initial_population' parameter. In this case, the values of the 2 parameters sol_per_pop and num_genes will be deduced.
# 2) Assign integer values to the 'sol_per_pop' and 'num_genes' parameters so that PyGAD can create the initial population automatically.
# Traceback (most recent call last):
#   File "/Users/nikolaibabuhin/PycharmProjects/Команда_5_Росатом/venv/lib/python3.9/site-packages/pygad/pygad.py", line 413, in __init__
# ...

# %%
import numpy as np
import pygad

# Определение целевой функции
def fitness_function(solution, solution_idx):
    # Разделение генетической популяции на маршруты
    routes = np.split(solution, num_routes)

    # Вычисление значения целевой функции для каждого маршрута
    fitness_values = []
    for route in routes:
        # Вычисление значения целевой функции для данного маршрута
        # ...

        # Добавление значения целевой функции в список
        fitness_values.append(fitness_value)

    # Возвращение списка значений целевой функции для каждого маршрута
    return fitness_values

# Создание экземпляра генетического алгоритма
ga_instance = pygad.GA(num_generations=100,
                       num_parents_mating=10,
                       fitness_func=fitness_function)

# Запуск генетического алгоритма
ga_instance.run()

# Получение лучших решений для каждого маршрута
best_solutions = ga_instance.best_solution()
best_fitness = ga_instance.best_solution_fitness()

# Вывод результата
print("Лучшие решения для каждого маршрута:", best_solutions)
print("Значение целевой функции:", best_fitness)
# Out:
# Error creating the initial population:
#
# When the parameter 'initial_population' is None, then the 2 parameters 'sol_per_pop' and 'num_genes' cannot be None too.
# There are 2 options to prepare the initial population:
# 1) Assinging the initial population to the 'initial_population' parameter. In this case, the values of the 2 parameters sol_per_pop and num_genes will be deduced.
# 2) Assign integer values to the 'sol_per_pop' and 'num_genes' parameters so that PyGAD can create the initial population automatically.
# Traceback (most recent call last):
#   File "/Users/nikolaibabuhin/PycharmProjects/Команда_5_Росатом/venv/lib/python3.9/site-packages/pygad/pygad.py", line 413, in __init__
# ...

# %%
import numpy as np
import pygad
import matplotlib.pyplot as plt
import json

# Определение целевой функции
def fitness_function(solution, solution_idx):
    # Разделение генетической популяции на маршруты
    routes = np.split(solution, num_routes)

    # Вычисление значения целевой функции для каждого маршрута
    fitness_values = []
    for route in routes:
        # Вычисление значения целевой функции для данного маршрута
        # ...

        # Добавление значения целевой функции в список
        fitness_values.append(fitness_value)

    # Возвращение списка значений целевой функции для каждого маршрута
    return fitness_values

# Создание экземпляра генетического алгоритма
ga_instance = pygad.GA(num_generations=100,
                       num_parents_mating=10,
                       fitness_func=fitness_function)

# Запуск генетического алгоритма
ga_instance.run()

# Получение лучших решений для каждого маршрута
best_solutions = ga_instance.best_solution()
best_fitness = ga_instance.best_solution_fitness()

# Формирование данных для JSON
data = {
    "best_solutions": best_solutions,
    "best_fitness": best_fitness
}

# Сериализация данных в JSON-строку
json_data = json.dumps(data)

# Отправка JSON-строки
# ...

# Визуализация результатов
fig, ax = plt.subplots()

for i in range(num_routes):
    start_times = np.cumsum(best_solutions[i])
    task_lengths = [task_length for task_length in best_solutions[i]]
    ax.broken_barh([(start_times[j], task_lengths[j]) for j in range(len(start_times))], (10*i, 9))

ax.set_xlabel('Время')
ax.set_ylabel('Маршрут')
ax.set_title('Диаграмма Ганта')
ax.set_yticks([10*i+5 for i in range(num_routes)])
ax.set_yticklabels([f'Маршрут {i+1}' for i in range(num_routes)])

plt.show()
